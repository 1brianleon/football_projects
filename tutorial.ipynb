# %%
import json 
import time 
import sys
import re
import numpy as np
import pandas as pd 
from bs4 import BeautifulSoup
from pydantic import BaseModel
from typing import List, Optional 
from selenium import webdriver
from supabase import create_client, Client

from selenium.common.exceptions import NoSuchElementException, WebDriverException
from selenium.webdriver.common.by import By

# %%
def prepend_base_url(match_urls):
    return ['https://www.whoscored.com' + url['url'] for url in match_urls]

# %%
def getLeagueUrls(minimize_window=True):
    
    driver = webdriver.Chrome()
    
    if minimize_window:
        driver.minimize_window()
        
    driver.get(main_url)
    league_names = []
    league_urls = []
    n_tournaments = len(BeautifulSoup(driver.find_element(By.ID, 'popular-tournaments-list').get_attribute('innerHTML')).findAll('li'))
    for i in range(n_tournaments):
        league_name = driver.find_element(By.XPATH, '//*[@id="popular-tournaments-list"]/li['+str(i+1)+']/a').text
        league_link = driver.find_element(By.XPATH, '//*[@id="popular-tournaments-list"]/li['+str(i+1)+']/a').get_attribute('href')
        league_names.append(league_name)
        league_urls.append(league_link)
        
    for link in league_urls:
        if 'Russia' in link:
            r_index = league_urls.index(link)
            
    league_names[r_index] = 'Russian Premier League'
    
    leagues = {}
    for name,link in zip(league_names,league_urls):
        leagues[name] = link
    driver.close()
    return leagues

# %%
def getMatchUrls(comp_urls, competition, season, maximize_window=True):

    driver = webdriver.Chrome()
    
    if maximize_window:
        driver.maximize_window()
    
    comp_url = comp_urls[competition]
    driver.get(comp_url)
    time.sleep(5)
    
    seasons = driver.find_element(By.XPATH, '//*[@id="seasons"]').get_attribute('innerHTML').split(sep='\n')
    seasons = [i for i in seasons if i]
    
    
    for i in range(1, len(seasons)+1):
        if driver.find_element(By.XPATH, '//*[@id="seasons"]/option['+str(i)+']').text == season:
            driver.find_element(By.XPATH, '//*[@id="seasons"]/option['+str(i)+']').click()
            
            time.sleep(5)
            try:
                stages = driver.find_element(By.XPATH, '//*[@id="stages"]').get_attribute('innerHTML').split(sep='\n')
                stages = [i for i in stages if i]
                
                all_urls = []
            
                for i in range(1, len(stages)+1):
                    if competition == 'Champions League' or competition == 'Europa League':
                        if 'Group Stages' in driver.find_element(By.XPATH, '//*[@id="stages"]/option['+str(i)+']').text or 'Final Stage' in driver.find_element_by_xpath('//*[@id="stages"]/option['+str(i)+']').text:
                            driver.find_element(By.XPATH, '//*[@id="stages"]/option['+str(i)+']').click()
                            time.sleep(5)
                            
                            driver.execute_script("window.scrollTo(0, 400)") 
                            
                            match_urls = getUrlData(driver)
                            
                            all_urls += match_urls
                        else:
                            continue
                    
                    elif competition == 'Major League Soccer':
                        if 'Grp. ' not in driver.find_element(By.XPATH, '//*[@id="stages"]/option['+str(i)+']').text: 
                            driver.find_element(By.XPATH, '//*[@id="stages"]/option['+str(i)+']').click()
                            time.sleep(5)
                        
                            driver.execute_script("window.scrollTo(0, 400)")
                            
                            match_urls = getUrlData(driver)
                            
                            all_urls += match_urls
                        else:
                            continue
                        
                    else:
                        driver.find_element(By.XPATH, '//*[@id="stages"]/option['+str(i)+']').click()
                        time.sleep(5)
                    
                        driver.execute_script("window.scrollTo(0, 400)")
                        
                        match_urls = getUrlData(driver)
                        
                        all_urls += match_urls
                
            except NoSuchElementException:
                all_urls = []
                
                driver.execute_script("window.scrollTo(0, 400)")
                
                match_urls = getUrlData(driver)
                
                all_urls += match_urls
            
            # Remove duplicates from all_urls
            remove_dup = [dict(t) for t in {tuple(sorted(d.items())) for d in all_urls}]
            remove_dup = list(filter(None, remove_dup))
            
            driver.close() 
    
            return remove_dup
     
    season_names = [re.search(r'\>(.*?)\<',season).group(1) for season in seasons]
    driver.close() 
    print('Seasons available: {}'.format(season_names))
    raise('Season Not Found.')

# %%
def getUrlData(driver):

    matches_ls = []
    while True:
        table_rows = driver.find_elements(By.CLASS_NAME, 'divtable-row')
        if len(table_rows) == 0:
            if('is-disabled' in driver.find_element(By.XPATH, '//*[@id="date-controller"]/a[1]').get_attribute('class').split()):
                break
            else:
                driver.find_element(By.XPATH, '//*[@id="date-controller"]/a[1]').click()
        for row in table_rows:
            match_dict = {}
            element = BeautifulSoup(row.get_attribute('innerHTML'), features='lxml')
            link_tag = element.find("a", {"class":"result-1 rc"})
            if type(link_tag) is not type(None):
                match_dict['url'] = link_tag.get("href")
            matches_ls.append(match_dict)
                
        prev_month = driver.find_element(By.XPATH, '//*[@id="date-controller"]/a[1]').click()
        time.sleep(2)
        if driver.find_element(By.XPATH, '//*[@id="date-controller"]/a[1]').get_attribute('title') == 'No data for previous week':
            table_rows = driver.find_elements(By.CLASS_NAME, 'divtable-row')
            for row in table_rows:
                match_dict = {}
                element = BeautifulSoup(row.get_attribute('innerHTML'), features='lxml')
                link_tag = element.find("a", {"class":"result-1 rc"})
                if type(link_tag) is not type(None):
                    match_dict['url'] = link_tag.get("href")
                matches_ls.append(match_dict)
            break
    
    matches_ls = list(filter(None, matches_ls))

    return matches_ls

# %%
main_url = 'https://www.whoscored.com/'

# %%
league_urls = getLeagueUrls()
league_urls
# Out:
# {'Premier League': 'https://www.whoscored.com/Regions/252/Tournaments/2/England-Premier-League',
#  'Serie A': 'https://www.whoscored.com/Regions/108/Tournaments/5/Italy-Serie-A',
#  'LaLiga': 'https://www.whoscored.com/Regions/206/Tournaments/4/Spain-LaLiga',
#  'Bundesliga': 'https://www.whoscored.com/Regions/81/Tournaments/3/Germany-Bundesliga',
#  'Ligue 1': 'https://www.whoscored.com/Regions/74/Tournaments/22/France-Ligue-1',
#  'Liga Portugal': 'https://www.whoscored.com/Regions/177/Tournaments/21/Portugal-Liga-Portugal',
#  'Eredivisie': 'https://www.whoscored.com/Regions/155/Tournaments/13/Netherlands-Eredivisie',
#  'Russian Premier League': 'https://www.whoscored.com/Regions/182/Tournaments/77/Russia-Premier-League',
#  'Brasileirão': 'https://www.whoscored.com/Regions/31/Tournaments/95/Brazil-Brasileir%C3%A3o',
#  'Major League Soccer': 'https://www.whoscored.com/Regions/233/Tournaments/85/USA-Major-League-Soccer',
#  'Super Lig': 'https://www.whoscored.com/Regions/225/Tournaments/17/Turkey-Super-Lig',
#  'Championship': 'https://www.whoscored.com/Regions/252/Tournaments/7/England-Championship',
#  'Premiership': 'https://www.whoscored.com/Regions/253/Tournaments/20/Scotland-Premiership',
#  'League One': 'https://www.whoscored.com/Regions/252/Tournaments/8/England-League-One',
#  'League Two': 'https://www.whoscored.com/Regions/252/Tournaments/9/England-League-Two',
#  'Liga Profesional': 'https://www.whoscored.com/Regions/11/Tournaments/68/Argentina-Liga-Profesional',
#  'Jupiler Pro League': 'https://www.whoscored.com/Regions/22/Tournaments/18/Belgium-Jupiler-Pro-League',
#  '2. Bundesliga': 'https://www.whoscored.com/Regions/81/Tournaments/6/Germany-2-Bundesliga',
#  'Champions League': 'https://www.whoscored.com/Regions/250/Tournaments/12/Europe-Champions-League',
#  'Europa League': 'https://www.whoscored.com/Regions/250/Tournaments/30/Europe-Europa-League',
#  'FA Cup': 'https://www.whoscored.com/Regions/252/Tournaments/26/England-FA-Cup',
#  'League Cup': 'https://www.whoscored.com/Regions/252/Tournaments/29/England-League-Cup',
#  'European Championship': 'https://www.whoscored.com/Regions/247/Tournaments/124/International-European-Championship',
#  "Women's Super League": 'https://www.whoscored.com/Regions/252/Tournaments/739/England-Women-s-Super-League',
#  'Africa Cup of Nations': 'https://www.whoscored.com/Regions/247/Tournaments/104/International-Africa-Cup-of-Nations'}

# %%
match_urls = getMatchUrls(comp_urls=league_urls, competition='LaLiga', season='2023/2024')

# %%
formatted_urls = prepend_base_url(match_urls)
formatted_urls
# Out:
# ['https://www.whoscored.com/Matches/1734648/Live/Spain-LaLiga-2023-2024-Sevilla-Girona',
#  'https://www.whoscored.com/Matches/1734649/Live/Spain-LaLiga-2023-2024-Valencia-Osasuna',
#  'https://www.whoscored.com/Matches/1734920/Live/Spain-LaLiga-2023-2024-Celta-Vigo-Real-Sociedad',
#  'https://www.whoscored.com/Matches/1734858/Live/Spain-LaLiga-2023-2024-Atletico-Madrid-Las-Palmas',
#  'https://www.whoscored.com/Matches/1734707/Live/Spain-LaLiga-2023-2024-Osasuna-Sevilla',
#  'https://www.whoscored.com/Matches/1734904/Live/Spain-LaLiga-2023-2024-Real-Sociedad-Villarreal',
#  'https://www.whoscored.com/Matches/1734689/Live/Spain-LaLiga-2023-2024-Valencia-Atletico-Madrid',
#  'https://www.whoscored.com/Matches/1734682/Live/Spain-LaLiga-2023-2024-Mallorca-Cadiz',
#  'https://www.whoscored.com/Matches/1734917/Live/Spain-LaLiga-2023-2024-Sevilla-Deportivo-Alaves',
#  'https://www.whoscored.com/Matches/1734932/Live/Spain-LaLiga-2023-2024-Rayo-Vallecano-Cadiz',
#  'https://www.whoscored.com/Matches/1734786/Live/Spain-LaLiga-2023-2024-Real-Betis-Getafe',
#  'https://www.whoscored.com/Matches/1734753/Live/Spain-LaLiga-2023-2024-Athletic-Club-Atletico-Madrid',
#  'https://www.whoscored.com/Matches/1734997/Live/Spain-LaLiga-2023-2024-Real-Betis-Osasuna',
#  'https://www.whoscored.com/Matches/1734656/Live/Spain-LaLiga-2023-2024-Real-Betis-Mallorca',
#  'https://www.whoscored.com/Matches/1734895/Live/Spain-LaLiga-2023-2024-Athletic-Club-Real-Sociedad',
#  'https://www.whoscored.com/Matches/1734855/Live/Spain-LaLiga-2023-2024-Getafe-Rayo-Vallecano',
#  'https://www.whoscored.com/Matches/1734751/Live/Spain-LaLiga-2023-2024-Almeria-Mallorca',
#  'https://www.whoscored.com/Matches/1734957/Live/Spain-LaLiga-2023-2024-Getafe-Granada',
#  'https://www.whoscored.com/Matches/1734759/Live/Spain-LaLiga-2023-2024-Real-Madrid-Villarreal',
#  'https://www.whoscored.com/Matches/1734683/Live/Spain-LaLiga-2023-2024-Getafe-Osasuna',
#  'https://www.whoscored.com/Matches/1734632/Live/Spain-LaLiga-2023-2024-Barcelona-Cadiz',
#  'https://www.whoscored.com/Matches/1734677/Live/Spain-LaLiga-2023-2024-Atletico-Madrid-Villarreal',
#  'https://www.whoscored.com/Matches/1734745/Live/Spain-LaLiga-2023-2024-Granada-Athletic-Club',
#  'https://www.whoscored.com/Matches/1734655/Live/Spain-LaLiga-2023-2024-Atletico-Madrid-Deportivo-Alaves',
#  'https://www.whoscored.com/Matches/1734834/Live/Spain-LaLiga-2023-2024-Sevilla-Atletico-Madrid',
#  'https://www.whoscored.com/Matches/1734667/Live/Spain-LaLiga-2023-2024-Osasuna-Girona',
#  'https://www.whoscored.com/Matches/1734635/Live/Spain-LaLiga-2023-2024-Deportivo-Alaves-
Live/Spain-LaLiga-2023-2024-Real-Sociedad-Real-Betis',
#  'https://www.whoscored.com/Matches/1734764/Live/Spain-LaLiga-2023-2024-Mallorca-Valencia',
#  'https://www.whoscored.com/Matches/1734758/Live/Spain-LaLiga-2023-2024-Atletico-Madrid-Real-Sociedad',
#  'https://www.whoscored.com/Matches/1734735/Live/Spain-LaLiga-2023-2024-Cadiz-Osasuna',
#  'https://www.whoscored.com/Matches/1734835/Live/Spain-LaLiga-2023-2024-Rayo-Vallecano-Valencia',
#  'https://www.whoscored.com/Matches/1734937/Live/Spain-LaLiga-2023-2024-Real-Betis-Barcelona',
#  'https://www.whoscored.com/Matches/1734905/Live/Spain-LaLiga-2023-2024-Cadiz-Valencia',
#  'https://www.whoscored.com/Matches/1734642/Live/Spain-LaLiga-2023-2024-Celta-Vigo-Real-Madrid',
#  'https://www.whoscored.com/Matches/1734730/Live/Spain-LaLiga-2023-2024-Villarreal-Girona',
#  'https://www.whoscored.com/Matches/1734866/Live/Spain-LaLiga-2023-2024-Rayo-Vallecano-Real-Madrid',
#  'https://www.whoscored.com/Matches/1734736/Live/Spain-LaLiga-2023-2024-Celta-Vigo-Deportivo-Alaves',
#  'https://www.whoscored.com/Matches/1734695/Live/Spain-LaLiga-2023-2024-Rayo-Vallecano-Deportivo-Alaves',
#  'https://www.whoscored.com/Matches/1734865/Live/Spain-LaLiga-2023-2024-Osasuna-Almeria',
#  'https://www.whoscored.com/Matches/1734919/Live/Spain-LaLiga-2023-2024-Athletic-Club-Barcelona',
#  'https://www.whoscored.com/Matches/1734949/Live/Spain-LaLiga-2023-2024-Atletico-Madrid-Valencia',
#  'https://www.whoscored.com/Matches/1734743/Live/Spain-LaLiga-2023-2024-Atletico-Madrid-Almeria',
#  'https://www.whoscored.com/Matches/1734718/Live/Spain-LaLiga-2023-2024-Osasuna-Real-Sociedad',
#  'https://www.whoscored.com/Matches/1734665/Live/Spain-LaLiga-2023-2024-Getafe-Cadiz',
#  'https://www.whoscored.com/Matches/1734908/Live/Spain-LaLiga-2023-2024-Getafe-Real-Madrid',
#  'https://www.whoscored.com/Matches/1734748/Live/Spain-LaLiga-2023-2024-Girona-Real-Madrid',
#  'https://www.whoscored.com/Matches/1734914/Live/Spain-LaLiga-2023-2024-Mallorca-Celta-Vigo',
#  'https://www.whoscored.com/Matches/1734783/Live/Spain-LaLiga-2023-2024-Athletic-Club-Mallorca',
#  'https://www.whoscored.com/Matches/1734886/Live/Spain-LaLiga-2023-2024-Real-Madrid-Mallorca',
#  'https://www.whoscored.com/Matches/1734823/Live/Spain-LaLiga-2023-2024-Real-Betis-Girona',
#  'https://www.whoscored.com/Matches/1734700/Live/Spain-LaLiga-2023-2024-Deportivo-Alaves-Granada',
#  'https://www.whoscored.com/Matches/1734638/Live/Spain-LaLiga-2023-2024-Real-Sociedad-Celta-Vigo',
#  'https://www.whoscored.com/Matches/1734679/Live/Spain-LaLiga-2023-2024-Real-Madrid-Valencia',
#  'https://www.whoscored.com/Matches/1734709/Live/Spain-LaLiga-2023-2024-Rayo-Vallecano-Villarreal',
#  'https://www.whoscored.com/Matches/1734676/Live/Spain-LaLiga-2023-2024-Athletic-Club-Cadiz',
#  'https://www.whoscored.com/Matches/1734741/Live/Spain-LaLiga-2023-2024-Deportivo-Alaves-Las-Palmas',
#  'https://www.whoscored.com/Matches/1734960/Live/Spain-LaLiga-2023-2024-Las-Palmas-Real-Madrid',
#  'https://www.whoscored.com/Matches/1734688/Live/Spain-LaLiga-2023-2024-Osasuna-Las-Palmas',
#  'https://www.whoscored.com/Matches/1734637/Live/Spain-LaLiga-2023-2024-Real-Betis-Atletico-Madrid',
#  'https://www.whoscored.com/Matches/1734629/Live/Spain-LaLiga-2023-2024-Real-Sociedad-Girona',
#  'https://www.whoscored.com/Matches/1735000/Live/Spain-LaLiga-2023-2024-Granada-Villarreal',
#  'https://www.whoscored.com/Matches/1734687/Live/Spain-LaLiga-2023-2024-Villarreal-Almeria',
#  'https://www.whoscored.com/Matches/1734978/Live/Spain-LaLiga-2023-2024-Valencia-Getafe',
#  'https://www.whoscored.com/Matches/1734698/Live/Spain-LaLiga-2023-2024-Real-Sociedad-Sevilla',
#  'https://www.whoscored.com/Matches/1734766/Live/Spain-LaLiga-2023-2024-Deportivo-Alaves-Real-Betis',
#  'https://www.whoscored.com/Matches/1734929/Live/Spain-LaLiga-2023-2024-Celta-Vigo-Almeria',
#  'https://www.whoscored.com/Matches/1734711/Live/Spain-LaLiga-2023-2024-Deportivo-Alaves-Athletic-Club',
#  'https://www.whoscored.com/Matches/1734962/Live/Spain-LaLiga-2023-2024-Girona-Osasuna',
#  'https://www.whoscored.com/Matches/1734887/Live/Spain-LaLiga-2023-2024-Real-Betis-Deportivo-Alaves',
#  'https://www.whoscored.com/Matches/1734994/Live/Spain-LaLiga-2023-2024-Almeria-Las-Palmas',
#  'https://www.whoscored.com/Matches/1734902/Live/Spain-LaLiga-2023-2024-Real-Betis-Granada',
#  'https://www.whoscored.com/Matches/1734815/Live/Spain-LaLiga-2023-2024-Athletic-Club-Las-Palmas',
#  'https://www.whoscored.com/Matches/1734995/Live/Spain-LaLiga-2023-2024-Athletic-Club-Valencia',
#  'https://www.whoscored.com/Matches/1734789/Live/Spain-LaLiga-2023-2024-Girona-Real-Sociedad',
#  'https://www.whoscored.com/Matches/1734772/Live/Spain-LaLiga-2023-2024-Villarreal-Las-Palmas',
#  'https://www.whoscored.com/Matches/1734775/Live/Spain-LaLiga-2023-2024-Barcelona-Athletic-Club',
#  'https://www.whoscored.com/Matches/1734959/Live/Spain-LaLiga-2023-2024-Real-Betis-Villarreal',
#  'https://www.whoscored.com/Matches/1734777/Live/Spain-LaLiga-2023-2024-Getafe-Real-Betis',
#  'https://www.whoscored.com/Matches/1734733/Live/Spain-LaLiga-2023-2024-Real-Betis-Real-Madrid',
#  'https://www.whoscored.com/Matches/1734883/Live/Spain-LaLiga-2023-2024-Granada-Cadiz',
#  'https://www.whoscored.com/Matches/1734673/Live/Spain-LaLiga-2023-2024-Almeria-Real-Sociedad',
#  'https://www.whoscored.com/Matches/1734624/Live/Spain-LaLiga-2023-2024-Celta-Vigo-Osasuna',
#  'https://www.whoscored.com/Matches/1734869/Live/Spain-LaLiga-2023-2024-Sevilla-Athletic-Club',
#  'https://www.whoscored.com/Matches/1734819/Live/Spain-LaLiga-2023-2024-Atletico-Madrid-Getafe',
#  'https://www.whoscored.com/Matches/1734839/Live/Spain-LaLiga-2023-2024-Granada-Sevilla',
#  'https://www.whoscored.com/Matches/1734623/Live/Spain-LaLiga-2023-2024-Atletico-Madrid-Granada',
#  'https://www.whoscored.com/Matches/1734765/Live/Spain-LaLiga-2023-2024-Las-Palmas-Cadiz',
#  'https://www.whoscored.com/Matches/1734925/Live/Spain-LaLiga-2023-2024-Getafe-Las-Palmas',
#  'https://www.whoscored.com/Matches/1734672/Live/Spain-LaLiga-2023-2024-Real-Madrid-Getafe',
#  'https://www.whoscored.com/Matches/1734633/Live/Spain-LaLiga-2023-2024-Mallorca-Villarreal',
#  'https://www.whoscored.com/Matches/1734712/Live/Spain-LaLiga-2023-2024-Almeria-Real-Betis',
#  'https://www.whoscored.com/Matches/1734708/Live/Spain-LaLiga-2023-2024-Valencia-Celta-Vigo',
#  'https://www.whoscored.com/Matches/1734996/Live/Spain-LaLiga-2023-2024-Barcelona-Real-Madrid',
#  'https://www.whoscored.com/Matches/1734756/Live/Spain-LaLiga-2023-2024-Rayo-Vallecano-Mallorca',
#  'https://www.whoscored.com/Matches/1734684/Live/Spain-LaLiga-2023-2024-Granada-Getafe',
#  'https://www.whoscored.com/Matches/1734773/Live/Spain-LaLiga-2023-2024-Las-Palmas-Rayo-Vallecano',
#  'https://www.whoscored.com/Matches/1734901/Live/Spain-LaLiga-2023-2024-Real-Madrid-Sevilla',
#  'https://www.whoscored.com/Matches/1734768/Live/Spain-LaLiga-2023-2024-Athletic-Club-Almeria',
#  'https://www.whoscored.com/Matches/1734671/Live/Spain-LaLiga-2023-2024-Valencia-Granada',
#  'https://www.whoscored.com/Matches/1734893/Live/Spain-LaLiga-2023-2024-Barcelona-Getafe',
#  'https://www.whoscored.com/Matches/1734681/Live/Spain-LaLiga-2023-2024-Celta-Vigo-Mallorca',
#  'https://www.whoscored.com/Matches/1734636/Live/Spain-LaLiga-2023-2024-Osasuna-Athletic-Club',
#  'https://www.whoscored.com/Matches/1734818/Live/Spain-LaLiga-2023-2024-Barcelona-Granada',
#  'https://www.whoscored.com/Matches/1734664/Live/Spain-LaLiga-2023-2024-Girona-Las-Palmas',
#  'https://www.whoscored.com/Matches/1734807/Live/Spain-LaLiga-2023-2024-Villarreal-Cadiz',
#  'https://www.whoscored.com/Matches/1734874/Live/Spain-LaLiga-2023-2024-Celta-Vigo-Barcelona']
